# %%
from task5a_structured_streaming import StructuredStreaming

# %%
streaming = StructuredStreaming()
streaming.readFile()
streaming.data_transform()
streaming.aggregate()
streaming.struc_streaming()
# Out:
#  Initializing Spark session for 'StructuredStreaming'...
# 25/08/29 23:24:18 WARN Utils: Your hostname, LAPTOP-E902JBKI.localdomain resolves to a loopback address: 127.0.1.1; using 10.255.255.254 instead (on interface lo)
# 25/08/29 23:24:18 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/08/29 23:24:18 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/08/29 23:24:19 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 25/08/29 23:24:19 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# Spark session created successfully.
# ...

# %%
streaming.demo()
# Out:
# ===== Snapshot 1 =====
# --- Cleaned Pollutants ---
# +----+----+---+----+----+---+---+---------------+
# |Date|Time|CO |NMHC|C6H6|NOx|NO2|event_timestamp|
# +----+----+---+----+----+---+---+---------------+
# +----+----+---+----+----+---+---+---------------+
#
# --- Pollutant Averages ---
# +---------+-----------+
# |pollutant|avg_reading|
# +---------+-----------+
# +---------+-----------+
# [Stage 3:============> (183 + 12) / 200][Stage 4:>                  (0 + 0) / 1]
# ===== Snapshot 2 =====
# --- Cleaned Pollutants ---
# +----+----+---+----+----+---+---+---------------+
# |Date|Time|CO |NMHC|C6H6|NOx|NO2|event_timestamp|
# +----+----+---+----+----+---+---+---------------+
# +----+----+---+----+----+---+---+---------------+
#
# --- Pollutant Averages ---
# +---------+-----------+
# |pollutant|avg_reading|
# +---------+-----------+
# +---------+-----------+
# ...

# %%
streaming.stop()
